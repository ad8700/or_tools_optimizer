# %%
import sys
import os
print(sys.prefix)
print(os.environ['CONDA_DEFAULT_ENV'])
# Out:
# C:\Users\andrew.domenico\AppData\Local\Continuum\anaconda3
# base

# %%
from __future__ import print_function
import pandas as pd
import numpy as np
import os
from IPython.display import display
from math import sin, cos, sqrt, atan2, radians
from geopy import distance
from geopy.distance import great_circle
from geopy.distance import vincenty
from sklearn.neighbors import DistanceMetric
import datetime
from datetime import datetime as dt
from datetime import timedelta
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp
# !{sys.executable} -m pip install ortools

taskFile = "C:/Users/andrew.domenico/OneDrive - Accenture/Documents/CTL/Dispatch Optimization/task.csv"

#import the task file
pwd = os.getcwd()
os.chdir(os.path.dirname(taskFile))
taskData = pd.read_csv(os.path.basename(taskFile))
os.chdir(pwd)
pd.options.display.max_columns = None
# Out:
# Requirement already satisfied: ortools in c:\users\andrew.domenico\appdata\roaming\python\python37\site-packages (7.5.7466)
# Requirement already satisfied: six>=1.10 in c:\users\andrew.domenico\appdata\local\continuum\anaconda3\lib\site-packages (from ortools) (1.14.0)
# Requirement already satisfied: protobuf>=3.11.2 in c:\users\andrew.domenico\appdata\local\continuum\anaconda3\lib\site-packages (from ortools) (3.11.2)
# Requirement already satisfied: setuptools in c:\users\andrew.domenico\appdata\local\continuum\anaconda3\lib\site-packages (from protobuf>=3.11.2->ortools) (41.0.1)

# %%
#drop columns with 100% missing data
taskData = taskData[['SerialNo','ExternalRefID','CallID','CTLDispatchCallID','CTLAggregationID',
                     'Number','EarlyStart','DueDate','Priority','Area','Region','District','Postcode','TaskType', 
                     'Duration','NumberOfRequiredEngineers','AppointmentStart','AppointmentFinish',
                     'Latitude','Longitude','Street','City','State','CountryID','CTLDispatchReady', 
                     'ES+duration','AS+duration','(AS+duration>=DD','(ES+duration>=DD','Duration (hh:mm:ss)', 
                     'DD-ES','ES>=DD','DD-AS','AS>=DD','AF>DD','Note']]

#drop rows where appointment Start is NaN

taskData = taskData.dropna(subset=['AppointmentStart', 'AppointmentFinish'])

taskData.head()
# Out:
#     SerialNo  ExternalRefID  CallID  CTLDispatchCallID CTLAggregationID  \
# 4          5         296995  296995  MRNV4306921001A00     R/1446647892
# 5          6         359391  359391  MRNV1244662001A00     R/1448416122
# 10        11         433583  433583  MRNV0262593001A00     R/1450669577
# 11        12         463745  463745  MRWI4297997001A00     R/1451570992
# 12        13         471971  471971  MRNV3256826002A00     R/1451829032
#
#     Number           EarlyStart              DueDate  Priority Area  \
# 4        1  2017-10-29T07:00:00  2017-10-29T19:00:00         4   NV
# 5        1  2017-10-28T07:00:00  2017-10-28T19:00:00         4   NV
# 10       1  2017-10-27T07:00:00  2017-10-27T19:00:00         4   NV
# 11       1  2017-10-30T07:00:00  2017-10-30T19:00:00         4   WI
# 12       1  2017-10-30T07:00:00  2017-10-30T19:00:00         4   NV
#
#                        Region      District     Postcode       TaskType  \
# 4                   Las Vegas  West West NV  891444443.0  XXXXXXXXXXXIH
# 5                   Las Vegas  West West NV  891447009.0  HSBNDA2FANRIN
# 10                  Las Vegas  West West NV  891172668.0  PRVDSL2FCHRIN
# 11  Northernwestern Wisconsin   Superior WI  548806275.0  HSBNDV2FCHRIN
# 12                  Las Vegas  Henderson NV  890110863.0  HSADSL2SCHRIN
#
#     Duration  NumberOfRequiredEngineers     AppointmentStart  \
# 4       4260                          1  2017-10-29T13:00:00
# 5      14400                          1  2017-10-28T08:00:00
# 10      4800                          1  2017-10-27T08:00:00
# 11     13200                          1  2017-10-30T08:00:00
# 12      4200                          1  2017-10-30T08:00:00
#
#       AppointmentFinish  Latitude  Longitude  Street  City  State  \
# 4   2017-10-29T17:00:00  36165665 -115331120     NaN   NaN    NaN
# 5   2017-10-28T17:00:00  36186165 -115314710     NaN   NaN    NaN
# 10  2017-10-27T12:00:00  36141231 -115280350     NaN   NaN    NaN
# 11  2017-10-30T12:00:00  46668495  -92076134     NaN   NaN    NaN
# 12  2017-10-30T12:00:00  36074753 -114964700     NaN   NaN    NaN
#
#         CountryID  CTLDispatchReady       ES+duration  AS+duration  \
# 4   UNITED STATES              True   10/29/2017 8:11   2:11:00 PM
# 5   UNITED STATES              True  10/28/2017 11:00  12:00:00 PM
# 10  UNITED STATES              True   10/27/2017 8:20   9:20:00 AM
# 11  UNITED STATES              True  10/30/2017 10:40  11:40:00 AM
# 12  UNITED STATES              True   10/30/2017 8:10   9:10:00 AM
#
#    (AS+duration>=DD (ES+duration>=DD Duration (hh:mm:ss)         DD-ES ES>=DD  \
# 4                OK               OK          1:11:00 AM  0/1/00 12:00      D
# 5                OK               OK          4:00:00 AM  0/1/00 12:00      D
# 10               OK               OK          1:20:00 AM  0/1/00 12:00      D
# 11               OK               OK          3:40:00 AM  0/1/00 12:00      D
# 12               OK               OK          1:10:00 AM  0/1/00 12:00      D
#
#                   DD-AS AS>=DD AF>DD  Note
# 4   1900-01-00T06:00:00      D     D   NaN
# 5   1900-01-00T11:00:00      D     D   NaN
# 10  1900-01-00T11:00:00      D     D   NaN
# 11  1900-01-00T11:00:00      D     D   NaN
# 12  1900-01-00T11:00:00      D     D   NaN

# %%
#split date and time elements into separate columns
earlyStart = taskData["EarlyStart"].str.split("T", n = 1, expand = True)
taskData["EarlyStartDate"] = earlyStart[0]
taskData["EarlyStartTime"] = earlyStart[1]
taskData.drop(columns = ["EarlyStart"], inplace = True)

dueDate = taskData["DueDate"].str.split("T", n = 1, expand = True)
taskData["DueDateDay"] = dueDate[0]
taskData["DueDateTime"] = dueDate[1]
taskData.drop(columns = ["DueDate"], inplace = True)

aptStart = taskData["AppointmentStart"].str.split("T", n = 1, expand = True)
taskData["appointmentStartDate"] = aptStart[0]
taskData["appointmentStartTime"] = aptStart[1]
taskData.drop(columns = ["AppointmentStart"], inplace = True)

aptFinish = taskData["AppointmentFinish"].str.split("T", n = 1, expand = True)
taskData["appointmentFinishDate"] = aptFinish[0]
taskData["appointmentFinishTime"] = aptFinish[1]
taskData.drop(columns = ["AppointmentFinish"], inplace = True)

display(taskData)
# Out:
#       SerialNo  ExternalRefID  CallID        CTLDispatchCallID  \
# 4            5         296995  296995        MRNV4306921001A00
# 5            6         359391  359391        MRNV1244662001A00
# 10          11         433583  433583        MRNV0262593001A00
# 11          12         463745  463745        MRWI4297997001A00
# 12          13         471971  471971        MRNV3256826002A00
# 38               08:00:00            2017-10-30              12:00:00
# 41               16:00:00            2017-10-31              16:15:00
# 42               12:30:00            2017-10-29              12:45:00
# 43               08:00:00            2017-10-30              17:00:00
# 45               08:00:00            2017-10-30              17:00:00
# 46               08:00:00            2017-10-27              12:00:00
# 48               08:00:00            2017-10-27              17:00:00
# 49               08:00:00            2017-10-27              17:00:00
# 51               08:00:00            2017-10-28              17:00:00
# 52               08:00:00            2017-10-30              12:00:00
# 53               08:00:00            2017-10-27              17:00:00
# 55               08:00:00            2017-10-30              17:00:00
# 56               15:45:00            2017-10-07              16:00:00
# 58               08:00:00            2017-10-30              17:00:00
# 59               16:00:00            2017-10-07              16:15:00
# 62               08:00:00            2017-10-27              17:00:00
# ...                   ...                   ...                   ...
# 3639             13:00:00            2017-10-30              17:00:00
# 3640             13:00:00            2017-10-30              17:00:00
# 3642             11:40:00            2017-10-30              13:40:00
# 3645             11:54:00            2017-10-30              13:54:00
# 3646             11:57:00            2017-10-30              13:57:00
# 3650             12:11:00            2017-10-30              14:11:00
# 3652             12:13:00            2017-10-30              14:13:00
# 3653             12:13:00            2017-10-30              14:13:00
# 3658             12:28:00            2017-10-30              14:28:00
# 3660             08:00:00            2017-10-31              12:00:00
# 3663             12:40:00            2017-10-30              14:40:00
# 3664             12:58:00            2017-10-30              14:58:00
# 3665             12:59:00            2017-10-30              14:59:00
# 3667             13:07:00            2017-10-30              15:07:00
# 3668             13:14:00            2017-10-30              15:14:00
# 3670             13:20:00            2017-10-30              15:20:00
# 3673             13:31:00            2017-10-30              15:31:00
# 3674             13:35:00            2017-10-30              15:35:00
# 3680             13:42:00            2017-10-30              15:42:00
# 3681             17:00:00            2017-10-30              17:15:00
# 3682             13:58:00            2017-10-30              15:58:00
# 3683             14:13:00            2017-10-30              16:13:00
# 3684             16:45:00            2017-10-30              17:00:00
# 3685             14:39:00            2017-10-30              16:39:00
# 3687             14:57:00            2017-10-30              16:57:00
# 3688             15:45:00            2017-10-30              17:45:00
# 3696             16:05:00            2017-10-30              18:05:00
# 3697             16:07:00            2017-10-30              18:07:00
# 3698             16:37:00            2017-10-30              18:37:00
# 3699             16:42:00            2017-10-30              18:42:00
#
# [1652 rows x 40 columns]

# %%
#convert latitudes and longitudes into usable
taskData["Latitude"] = taskData["Latitude"].astype(str)
taskData["Longitude"] = taskData["Longitude"].astype(str)
taskData["Latitude"] = [l.replace('..', '.') for l in taskData.Latitude]
taskData["Longitude"] = [l.replace('..', '.') for l in taskData.Longitude]

taskData["lastSixLat"] = taskData["Latitude"].str[-6:]
taskData["trimmedLat"] = taskData["Latitude"].str[:-6]
taskData["Lat"] = taskData["trimmedLat"] + "." + taskData["lastSixLat"]
taskData.drop(columns = ["lastSixLat"], inplace = True)
taskData.drop(columns = ["trimmedLat"], inplace = True)
taskData.drop(columns = ["Latitude"], inplace = True)
taskData["Latitude"] = taskData["Lat"].astype(float)

taskData["lastSixLong"] = taskData["Longitude"].str[-6:]
taskData["trimmedLong"] = taskData["Longitude"].str[:-6]
taskData["Long"] = taskData["trimmedLong"] + "." + taskData["lastSixLong"]
taskData.drop(columns = ["lastSixLong"], inplace = True)
taskData.drop(columns = ["trimmedLong"], inplace = True)
taskData.drop(columns = ["Longitude"], inplace = True)
taskData["Longitude"] = taskData["Long"].astype(float)

#display(taskData)

# %%
distances = pd.DataFrame()
distances["Latitude"] = taskData.Latitude
distances["Longitude"] = taskData.Longitude
#distances['coords'] = zip(taskData.Latitude, taskData.Longitude)
distances.head()
# Out:
#      Latitude   Longitude
# 4   36.165665 -115.331120
# 5   36.186165 -115.314710
# 10  36.141231 -115.280350
# 11  46.668495  -92.076134
# 12  36.074753 -114.964700

# %%
#create an array of all distances
dfr = distances.copy()
dfr.Latitude = np.radians(distances.Latitude)
dfr.Longitude = np.radians(distances.Longitude)
hs = DistanceMetric.get_metric("haversine")
dist_array = (hs.pairwise(dfr)*6371) # Earth radius in km
display(dist_array)
# Out:
# array([[ 0.        ,  2.71396325,  5.30657986, ..., 18.6244814 ,
#         34.97035772, 15.87093614],
#        [ 2.71396325,  0.        ,  5.87186318, ..., 19.6567152 ,
#         34.80643886, 13.58365634],
#        [ 5.30657986,  5.87186318,  0.        , ..., 13.78537104,
#         29.67613836, 13.82095645],
#        ...,
#        [18.6244814 , 19.6567152 , 13.78537104, ...,  0.        ,
#         19.5429015 , 21.97975745],
#        [34.97035772, 34.80643886, 29.67613836, ..., 19.5429015 ,
#          0.        , 28.81087378],
#        [15.87093614, 13.58365634, 13.82095645, ..., 21.97975745,
#         28.81087378,  0.        ]])

# %%
#Calculate the time required to travel the distances and store to time array
#rate in kmph because distance is in km
rate = 56.327
#distance = rate * time so time = distance/rate
time_matrix = dist_array / 56.327
display(time_matrix)
# Out:
# array([[0.        , 0.04818228, 0.09421023, ..., 0.33064927, 0.62084538,
#         0.28176427],
#        [0.04818228, 0.        , 0.10424598, ..., 0.34897501, 0.61793525,
#         0.24115711],
#        [0.09421023, 0.10424598, 0.        , ..., 0.24473824, 0.52685459,
#         0.24537001],
#        ...,
#        [0.33064927, 0.34897501, 0.24473824, ..., 0.        , 0.34695442,
#         0.39021708],
#        [0.62084538, 0.61793525, 0.52685459, ..., 0.34695442, 0.        ,
#         0.51149313],
#        [0.28176427, 0.24115711, 0.24537001, ..., 0.39021708, 0.51149313,
#         0.        ]])

# %%
#Convert appointmentStartTime and appointmentFinishTime timestamps to minutes based on offset from midnight
#ex. 5:00 AM is 300 minutes after midnight
import datetime as dt

def min_mid_night(t_str=str):
    time = dt.datetime.strptime(t_str, "%H:%M:%S")
    return time.hour*60 + time.minute
taskData['apt_start_min'] = taskData.appointmentStartTime.apply(min_mid_night)
taskData['apt_finish_min'] = taskData.appointmentFinishTime.apply(min_mid_night)
taskData.head()
# Out:
#     SerialNo  ExternalRefID  CallID  CTLDispatchCallID CTLAggregationID  \
# 4          5         296995  296995  MRNV4306921001A00     R/1446647892
# 5          6         359391  359391  MRNV1244662001A00     R/1448416122
# 10        11         433583  433583  MRNV0262593001A00     R/1450669577
# 11        12         463745  463745  MRWI4297997001A00     R/1451570992
# 12        13         471971  471971  MRNV3256826002A00     R/1451829032
#
#     Number  Priority Area                     Region      District  \
# 4        1         4   NV                  Las Vegas  West West NV
# 5        1         4   NV                  Las Vegas  West West NV
# 10       1         4   NV                  Las Vegas  West West NV
# 11       1         4   WI  Northernwestern Wisconsin   Superior WI
# 12       1         4   NV                  Las Vegas  Henderson NV
#
#        Postcode       TaskType  Duration  NumberOfRequiredEngineers  Street  \
# 4   891444443.0  XXXXXXXXXXXIH      4260                          1     NaN
# 5   891447009.0  HSBNDA2FANRIN     14400                          1     NaN
# 10  891172668.0  PRVDSL2FCHRIN      4800                          1     NaN
# 11  548806275.0  HSBNDV2FCHRIN     13200                          1     NaN
# 12  890110863.0  HSADSL2SCHRIN      4200                          1     NaN
#
#     City  State      CountryID  CTLDispatchReady       ES+duration  \
# 4    NaN    NaN  UNITED STATES              True   10/29/2017 8:11
# 5    NaN    NaN  UNITED STATES              True  10/28/2017 11:00
# 10   NaN    NaN  UNITED STATES              True   10/27/2017 8:20
# 11   NaN    NaN  UNITED STATES              True  10/30/2017 10:40
# 12   NaN    NaN  UNITED STATES              True   10/30/2017 8:10
#
#     AS+duration (AS+duration>=DD (ES+duration>=DD Duration (hh:mm:ss)  \
# 4    2:11:00 PM               OK               OK          1:11:00 AM
# 5   12:00:00 PM               OK               OK          4:00:00 AM
# 10   9:20:00 AM               OK               OK          1:20:00 AM
# 11  11:40:00 AM               OK               OK          3:40:00 AM
# 12   9:10:00 AM               OK               OK          1:10:00 AM
#
#            DD-ES ES>=DD                DD-AS AS>=DD AF>DD  Note  \
# 4   0/1/00 12:00      D  1900-01-00T06:00:00      D     D   NaN
# 5   0/1/00 12:00      D  1900-01-00T11:00:00      D     D   NaN
# 10  0/1/00 12:00      D  1900-01-00T11:00:00      D     D   NaN
# 11  0/1/00 12:00      D  1900-01-00T11:00:00      D     D   NaN
# 12  0/1/00 12:00      D  1900-01-00T11:00:00      D     D   NaN
#
#    EarlyStartDate EarlyStartTime  DueDateDay DueDateTime appointmentStartDate  \
# 4      2017-10-29       07:00:00  2017-10-29    19:00:00           2017-10-29
# 5      2017-10-28       07:00:00  2017-10-28    19:00:00           2017-10-28
# 10     2017-10-27       07:00:00  2017-10-27    19:00:00           2017-10-27
# 11     2017-10-30       07:00:00  2017-10-30    19:00:00           2017-10-30
# 12     2017-10-30       07:00:00  2017-10-30    19:00:00           2017-10-30
#
#    appointmentStartTime appointmentFinishDate appointmentFinishTime  \
# 4              13:00:00            2017-10-29              17:00:00
# 5              08:00:00            2017-10-28              17:00:00
# 10             08:00:00            2017-10-27              12:00:00
# 11             08:00:00            2017-10-30              12:00:00
# 12             08:00:00            2017-10-30              12:00:00
#
#           Lat   Latitude         Long   Longitude  apt_start_min  \
# 4   36.165665  36.165665  -115.331120 -115.331120            780
# 5   36.186165  36.186165  -115.314710 -115.314710            480
# 10  36.141231  36.141231  -115.280350 -115.280350            480
# 11  46.668495  46.668495   -92.076134  -92.076134            480
# 12  36.074753  36.074753  -114.964700 -114.964700            480
#
#     apt_finish_min
# 4             1020
# 5             1020
# 10             720
# 11             720
# 12             720

# %%
#Create an array of arrival windows 
time_windows = np.array(taskData[['apt_start_min', 'apt_finish_min']])
display(time_windows)
# Out:
# array([[ 780, 1020],
#        [ 480, 1020],
#        [ 480,  720],
#        ...,
#        [ 967, 1087],
#        [ 997, 1117],
#        [1002, 1122]], dtype=int64)

# %%
def create_data_model():
  """Stores the data for the problem."""
  data = {}
  data["time_matrix"] = time_matrix
  data["time_windows"] = time_windows
#num_vehicles will need to be updated to be a count of the techs available from the daily schedule
  data["num_vehicles"] = 4
  data["depot"] = 0
  return data

def print_solution(data, manager, routing, assignment):
    """Prints assignment on console."""
    time_dimension = routing.GetDimensionOrDie('Time')
    total_time = 0
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = 'Route for vehicle {}:\n'.format(vehicle_id)
        while not routing.IsEnd(index):
            time_var = time_dimension.CumulVar(index)
            plan_output += '{0} Time({1},{2}) -> '.format(
                manager.IndexToNode(index), assignment.Min(time_var),
                assignment.Max(time_var))
            index = assignment.Value(routing.NextVar(index))
        time_var = time_dimension.CumulVar(index)
        plan_output += '{0} Time({1},{2})\n'.format(manager.IndexToNode(index),
                                                    assignment.Min(time_var),
                                                    assignment.Max(time_var))
        plan_output += 'Time of the route: {}min\n'.format(
            assignment.Min(time_var))
        print(plan_output)
        total_time += assignment.Min(time_var)
    print('Total time of all routes: {}min'.format(total_time))

def main():
    """Solve the VRP with time windows."""
    data = create_data_model()
    manager = pywrapcp.RoutingIndexManager(len(data['time_matrix']),
                                           data['num_vehicles'], data['depot'])
    routing = pywrapcp.RoutingModel(manager)

    def time_callback(from_index, to_index):
        """Returns the travel time between the two nodes."""
        # Convert from routing variable Index to time matrix NodeIndex.
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return data['time_matrix'][from_node][to_node]

    transit_callback_index = routing.RegisterTransitCallback(time_callback)
    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)
    time = 'Time'
    routing.AddDimension(
        transit_callback_index,
        30,  # allow waiting time
        30,  # maximum time per vehicle
        False,  # Don't force start cumul to zero.
        time)
    time_dimension = routing.GetDimensionOrDie(time)
    # Add time window constraints for each location except depot.
    for location_idx, time_window in enumerate(data['time_windows']):
        if location_idx == 0:
            continue
        index = manager.NodeToIndex(location_idx)
        time_dimension.CumulVar(index).SetRange(time_window[0], time_window[1])
    # Add time window constraints for each vehicle start node.
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        time_dimension.CumulVar(index).SetRange(data['time_windows'][0][0],
                                                data['time_windows'][0][1])
    for i in range(data['num_vehicles']):
        routing.AddVariableMinimizedByFinalizer(
            time_dimension.CumulVar(routing.Start(i)))
        routing.AddVariableMinimizedByFinalizer(
            time_dimension.CumulVar(routing.End(i)))
    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)
    assignment = routing.SolveWithParameters(search_parameters)
    if assignment:
        print_solution(data, manager, routing, assignment)

if __name__ == '__main__':
  main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-417d7c114cb5> in <module>
#      80
#      81 if __name__ == '__main__':
# ---> 82   main()
#
# <ipython-input-51-417d7c114cb5> in main()
#      61             continue
#      62         index = manager.NodeToIndex(location_idx)
# ---> 63         time_dimension.CumulVar(index).SetRange(time_window[0], time_window[1])
#      64     # Add time window constraints for each vehicle start node.
#      65     for vehicle_id in range(data['num_vehicles']):
#
# ~\AppData\Roaming\Python\Python37\site-packages\ortools\constraint_solver\pywrapcp.py in SetRange(self, l, u)
#    1096
#    1097     def SetRange(self, l: "int64", u: "int64") -> "void":
# -> 1098         return _pywrapcp.IntExpr_SetRange(self, l, u)
#    1099
#    1100     def SetValue(self, v: "int64") -> "void":
#
# TypeError: in method 'IntExpr_SetRange', argument 2 of type 'int64'
